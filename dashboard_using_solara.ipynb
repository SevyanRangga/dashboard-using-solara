# %%
# %pip install pandas matplotlib folium solara
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.7)
# Collecting solara
#   Downloading solara-1.50.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Collecting solara-server==1.50.0 (from solara-server[dev,starlette]==1.50.0->solara)
#   Downloading solara_server-1.50.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.50.0 (from solara-ui[all]==1.50.0->solara)
#   Downloading solara_ui-1.50.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (3.18.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (6.17.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (5.10.4)
# Collecting rich-click (from solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara)
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.50.0->solara)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.50.0->solara)
#   Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: starlette in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.50.0->solara) (0.46.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.50.0->solara) (0.35.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.50.0->solara) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (4.12.3)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.50.0->solara-ui[all]==1.50.0->solara)
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.50.0->solara-ui[all]==1.50.0->solara)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (7.7.1)
# Collecting reacton>=1.9 (from solara-ui==1.50.0->solara-ui[all]==1.50.0->solara)
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.50.0->solara) (5.5.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.50.0->solara) (3.8.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.50.0->solara) (2.19.2)
# Collecting pymdown-extensions (from solara-ui[all]==1.50.0->solara)
#   Downloading pymdown_extensions-10.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.6.15)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (3.0.15)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (6.4.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (5.8.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from reacton>=1.9->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (4.14.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (4.24.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pymdown-extensions->solara-ui[all]==1.50.0->solara) (6.0.2)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette->solara-server[dev,starlette]==1.50.0->solara) (4.9.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->solara-server[dev,starlette]==1.50.0->solara) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.50.0->solara) (1.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (4.3.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (3.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.50.0->solara-server[dev,starlette]==1.50.0->solara) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (25.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.50.0->solara-ui[all]==1.50.0->solara) (1.8.0)
# Downloading solara-1.50.0-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.50.0-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.50.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.6 MB/s eta 0:00:00
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 63.4 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 99.1 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.1 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.16-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 19.4 MB/s eta 0:00:00
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.3 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 31.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.5 MB/s eta 0:00:00
# Installing collected packages: watchdog, pymdown-extensions, jedi, watchfiles, rich-click, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara
# Successfully installed ipyvue-1.11.2 ipyvuetify-1.11.3 jedi-0.19.2 pymdown-extensions-10.16 reacton-1.9.1 rich-click-1.8.9 solara-1.50.0 solara-server-1.50.0 solara-ui-1.50.0 watchdog-6.0.0 watchfiles-1.1.0

# %%
import pandas as pd
from pathlib import Path
import solara

df_crime = pd.read_csv("SF_crime_sample.csv")

df_crime
# Out:
#       Unnamed: 0  IncidntNum        Category  \
# 0          50820   160525689        BURGLARY
# 1          11981   160334220   LARCENY/THEFT
# 2          74626   160740053   LARCENY/THEFT
# 3          60776   160619721        WARRANTS
# 4          34547   160345772        WARRANTS
# ...          ...         ...             ...
# 9995      137465   170013301  OTHER OFFENSES
# 9996       55811   160573939  OTHER OFFENSES
# 9997      120115   166110038   LARCENY/THEFT
# 9998        5069   160093943    NON-CRIMINAL
# 9999       35667   160373212         ASSAULT
#
#                                Descript  DayOfWeek                    Date  \
# 0     BURGLARY OF STORE, FORCIBLE ENTRY    Tuesday  06/28/2016 12:00:00 AM
# 1          PETTY THEFT FROM LOCKED AUTO     Friday  04/22/2016 12:00:00 AM
# 2           PETTY THEFT FROM A BUILDING     Monday  09/12/2016 12:00:00 AM
# 3                        WARRANT ARREST     Monday  08/01/2016 12:00:00 AM
# 4       ENROUTE TO OUTSIDE JURISDICTION  Wednesday  04/27/2016 12:00:00 AM
# ...                                 ...        ...                     ...
# 9995              HARASSING PHONE CALLS   Saturday  11/26/2016 12:00:00 AM
# 9996          LOST/STOLEN LICENSE PLATE   Thursday  07/07/2016 12:00:00 AM
# 9997       GRAND THEFT FROM LOCKED AUTO   Saturday  05/14/2016 12:00:00 AM
# 9998                         AIDED CASE     Monday  02/01/2016 12:00:00 AM
# 9999                            BATTERY     Friday  05/06/2016 12:00:00 AM
#
#        Time PdDistrict      Resolution                    Address           X  \
# 0     21:25    TARAVAL  ARREST, BOOKED    600 Block of LINCOLN WY -122.464850
# 1     19:00    TARAVAL            NONE  SAN JOSE AV / LAKEVIEW AV -122.450378
# 2     08:40  INGLESIDE            NONE       0 Block of PHELAN AV -122.452290
# 3     16:12       PARK  ARREST, BOOKED     1100 Block of SCOTT ST -122.437099
# 4     19:34   SOUTHERN  ARREST, BOOKED    600 Block of BRANNAN ST -122.399841
# ...     ...        ...             ...                        ...         ...
# 9995  12:00   SOUTHERN            NONE   1100 Block of MISSION ST -122.412834
# 9996  19:00    BAYVIEW            NONE      100 Block of TEXAS ST -122.395812
# 9997  03:30    CENTRAL            NONE        BAY ST / VANNESS AV -122.425111
# 9998  15:23    TARAVAL  ARREST, BOOKED  2600 Block of SAN JOSE AV -122.450635
# 9999  20:30    BAYVIEW            NONE   1300 Block of NEWHALL ST -122.391880
#
#               Y                               Location            PdId
# 0     37.765888  (37.7658875448653, -122.464850114297)  16052568905051
# 1     37.716169  (37.7161694707734, -122.450378171697)  16033422006243
# 2     37.725693  (37.7256933575703, -122.452289660492)  16074005306303
# 3     37.780352   (37.7803522156893, -122.43709942832)  16061972163010
# 4     37.775633  (37.7756327864282, -122.399841045579)  16034577262050
# ...         ...                                    ...             ...
# 9995  37.777790  (37.7777903094246, -122.412834332129)  17001330128135
# 9996  37.764531  (37.7645312950153, -122.395812338479)  16057393971010
# 9997  37.804146    (37.80414615262, -122.425110613231)  16611003806244
# 9998  37.715772  (37.7157715048394, -122.450634805259)  16009394351040
# 9999  37.735936  (37.7359364818345, -122.391879837176)  16037321204134
#
# [10000 rows x 14 columns]

# %%
df_crime["Category"] = df_crime["Category"].str.title()
df_crime["PdDistrict"] = df_crime["PdDistrict"].str.title()
df_crime
# Out:
#       Unnamed: 0  IncidntNum        Category  \
# 0          50820   160525689        Burglary
# 1          11981   160334220   Larceny/Theft
# 2          74626   160740053   Larceny/Theft
# 3          60776   160619721        Warrants
# 4          34547   160345772        Warrants
# ...          ...         ...             ...
# 9995      137465   170013301  Other Offenses
# 9996       55811   160573939  Other Offenses
# 9997      120115   166110038   Larceny/Theft
# 9998        5069   160093943    Non-Criminal
# 9999       35667   160373212         Assault
#
#                                Descript  DayOfWeek                    Date  \
# 0     BURGLARY OF STORE, FORCIBLE ENTRY    Tuesday  06/28/2016 12:00:00 AM
# 1          PETTY THEFT FROM LOCKED AUTO     Friday  04/22/2016 12:00:00 AM
# 2           PETTY THEFT FROM A BUILDING     Monday  09/12/2016 12:00:00 AM
# 3                        WARRANT ARREST     Monday  08/01/2016 12:00:00 AM
# 4       ENROUTE TO OUTSIDE JURISDICTION  Wednesday  04/27/2016 12:00:00 AM
# ...                                 ...        ...                     ...
# 9995              HARASSING PHONE CALLS   Saturday  11/26/2016 12:00:00 AM
# 9996          LOST/STOLEN LICENSE PLATE   Thursday  07/07/2016 12:00:00 AM
# 9997       GRAND THEFT FROM LOCKED AUTO   Saturday  05/14/2016 12:00:00 AM
# 9998                         AIDED CASE     Monday  02/01/2016 12:00:00 AM
# 9999                            BATTERY     Friday  05/06/2016 12:00:00 AM
#
#        Time PdDistrict      Resolution                    Address           X  \
# 0     21:25    Taraval  ARREST, BOOKED    600 Block of LINCOLN WY -122.464850
# 1     19:00    Taraval            NONE  SAN JOSE AV / LAKEVIEW AV -122.450378
# 2     08:40  Ingleside            NONE       0 Block of PHELAN AV -122.452290
# 3     16:12       Park  ARREST, BOOKED     1100 Block of SCOTT ST -122.437099
# 4     19:34   Southern  ARREST, BOOKED    600 Block of BRANNAN ST -122.399841
# ...     ...        ...             ...                        ...         ...
# 9995  12:00   Southern            NONE   1100 Block of MISSION ST -122.412834
# 9996  19:00    Bayview            NONE      100 Block of TEXAS ST -122.395812
# 9997  03:30    Central            NONE        BAY ST / VANNESS AV -122.425111
# 9998  15:23    Taraval  ARREST, BOOKED  2600 Block of SAN JOSE AV -122.450635
# 9999  20:30    Bayview            NONE   1300 Block of NEWHALL ST -122.391880
#
#               Y                               Location            PdId
# 0     37.765888  (37.7658875448653, -122.464850114297)  16052568905051
# 1     37.716169  (37.7161694707734, -122.450378171697)  16033422006243
# 2     37.725693  (37.7256933575703, -122.452289660492)  16074005306303
# 3     37.780352   (37.7803522156893, -122.43709942832)  16061972163010
# 4     37.775633  (37.7756327864282, -122.399841045579)  16034577262050
# ...         ...                                    ...             ...
# 9995  37.777790  (37.7777903094246, -122.412834332129)  17001330128135
# 9996  37.764531  (37.7645312950153, -122.395812338479)  16057393971010
# 9997  37.804146    (37.80414615262, -122.425110613231)  16611003806244
# 9998  37.715772  (37.7157715048394, -122.450634805259)  16009394351040
# 9999  37.735936  (37.7359364818345, -122.391879837176)  16037321204134
#
# [10000 rows x 14 columns]

# %%
def crime_filter(df, district_values, category_values):
    df_dist = df.loc[df["PdDistrict"].isin(district_values)]
    df_category = df_dist.loc[df_dist["Category"].isin(category_values)]
    return df_category


dff_crime = crime_filter(df_crime, ["Bayview", "Northern"], ["Vandalism", "Assault", "Robbery"])

# %%
import matplotlib.pyplot as plt

def crime_charts(df):
    cat_unique = df["Category"].value_counts()
    cat_unique = cat_unique.reset_index()

    dist_unique = df["PdDistrict"].value_counts()
    dist_unique = dist_unique.reset_index()

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    ax1.bar(cat_unique["Category"], cat_unique["count"])
    ax1.set_title("Amount of Criminal Case Based on Category")
    ax2.bar(dist_unique["PdDistrict"], dist_unique["count"])
    ax2.set_title("Amount of Criminal Case in Selected District")

    display(fig)
    plt.close(fig)


crime_charts(dff_crime)

# %%
import folium
import folium.plugins


def crime_map(df):
    latitude = 37.77
    longitude = -122.42

    sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

    incidents = folium.plugins.MarkerCluster().add_to(sanfran_map)

    # loop through the dataframe and add each data point to the mark cluster
    for (
        lat,
        lng,
        label,
    ) in zip(df.Y, df.X, df.Category):
        folium.Marker(
            location=[lat, lng],
            icon=None,
            popup=label,
        ).add_to(incidents)

    # show map
    display(sanfran_map)


crime_map(dff_crime.iloc[0:50, :])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_000c5fac52620417548b746a75ec7b4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_000c5fac52620417548b746a75ec7b4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_000c5fac52620417548b746a75ec7b4d = L.map(
#                 &quot;map_000c5fac52620417548b746a75ec7b4d&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4862f990925f6e7d291993591276c035 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4862f990925f6e7d291993591276c035.addTo(map_000c5fac52620417548b746a75ec7b4d);
#
#
#             var marker_cluster_aa7995301b624f0cb636c39473135f60 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_fb86b750e78ec64ae41e4928c942242f = L.marker(
#                 [37.8016108699901, -122.441398221863],
#                 {
# }
#             ).addTo(marker_cluster_aa7995301b624f0cb636c39473135f60);
#
#
#         var popup_6a4b25bcdbe48a04014952aad39a6e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ca70011d79ee082dde413826b4f68c = $(`&lt;div id=&quot;html_c9ca70011d79ee082dde413826b4f68c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_6a4b25bcdbe48a04014952aad39a6e3f.setContent(html_c9ca70011d79ee082dde413826b4f68c);
#
#
#
#         marker_fb86b750e78ec64ae41e4928c942242f.bindPopup(popup_6a4b25bcdbe48a04014952aad39a6e3f)
#         ;
#
#
#
#
#             var marker_2d0fa4d617d0e5c9a9dba97989d55b89 = L.marker(
#                 [37.773037747039, -122.430630284155],
#                 {
# }
#             ).addTo(marker_cluster_aa7995301b624f0cb636c39473135f60);
#
#
#         var popup_d39cdfbc40a21491c76152c2d4d67d15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e07194c4da656fe0b3bcd936799f174 = $(`&lt;div id=&quot;html_7e07194c4da656fe0b3bcd936799f174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_d39cdfbc40a21491c76152c2d4d67d15.setContent(html_7e07194c4da656fe0b3bcd936799f174);
#
#
#
#         marker_2d0fa4d617d0e5c9a9dba97989d55b89.bindPopup(popup_d39cdfbc40a21491c76152c2d4d67d15)
#         ;
#
#
#
#
#             var marker_13aa2afeed8d5d5ff97e36065ba9cd65 = L.marker(
#                 [37.789163624599794, -122.431378676586],
#                 {
# }
#             ).addTo(marker_cluster_aa7995301b624f0cb636c39473135f60);
#
#
#         var popup_b2d88327307f4c90ce1c20116d0c75da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_764adae02c475b34c93d48dadc189b8a = $(`&lt;div id=&quot;html_764adae02c475b34c93d48dadc189b8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vandalism&lt;/div&gt;`)[0];
#                 popup_b2d88327307f4c90ce1c20116d0c75da.setContent(html_764adae02c475b34c93d48dadc189b8a);
#
#
#
#         marker_13aa2afeed8d5d5ff97e36065ba9cd65.bindPopup(popup_b2d88327307f4c90ce1c20116d0c75da)
#         ;
#
#
#
#
#             var marker_1a5e12dfbd5f995c9c61e66dff3f81e7 = L.marker(
#                 [37.7661917267111, -122.400756349771],
#                 {
# }
#             ).addTo(marker_cluster_aa7995301b624f0cb636c39473135f60);
#
#
#         var popup_3fdeefde4716a5468596573317cf6e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b64a44322b48d3f4de3d79f7b2e11db1 = $(`&lt;div id=&quot;html_b64a44322b48d3f4de3d79f7b2e11db1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assault&lt;/div&gt;`)[0];
#                 popup_3fdeefde4716a5468596573317cf6e0f.setContent(html_b64a44322b48d3f4de3d79f7b2e11db1);
#
#
#
#         marker_1a5e12dfbd5f995c9c61e66dff3f81e7.bindPopup(popup_3fdeefde4716a5468596573317cf6e0f)
#         ;
#
#
#
#
#             var marker_92be2

# %%
import solara

districts = solara.reactive(["Bayview", "Northern"])
categories = solara.reactive(["Vandalism", "Assault", "Robbery"])
limit = solara.reactive(100)

# %%
@solara.component
def View():
    dff = crime_filter(df_crime, districts.value, categories.value)
    row_count = len(dff)
    if row_count > limit.value:
        solara.Warning(f"Only showing the first {limit.value} of {row_count:,} crimes on map")
    crime_map(dff.iloc[: limit.value])
    if row_count > 0:
        crime_charts(dff)
    else:
        solara.Warning("You filtered out all the data, no charts shown")


View()
# Out:
# Html(layout=None, style_='display: none', tag='span')
# Cannot show ipywidgets in text

# %%
limit.value = 70
districts.value = ["Soutern", "Northern"]

# %%
solara.SelectMultiple("District",
    all_values=[str(k) for k in df_crime["PdDistrict"].unique().tolist()],
    values=districts)
# Out:
# Html(layout=None, style_='display: none', tag='span')
# Cannot show ipywidgets in text

# %%
@solara.component
def Controls():
    solara.SelectMultiple("District", all_values=[str(k) for k in df_crime["PdDistrict"].unique().tolist()], values=districts)
    solara.SelectMultiple("Category", all_values=[str(k) for k in df_crime["Category"].unique().tolist()], values=categories)
    solara.Text("Maximum number of rows to show on map")
    solara.SliderInt("", value=limit, min=1, max=1000)


Controls()
# Out:
# Html(layout=None, style_='display: none', tag='span')
# Cannot show ipywidgets in text

# %%
# Note that we can read AND write reactive variables
categories.value = [*categories.value, "Warrants"]

# %%
@solara.component
def Page():
    with solara.Sidebar():
        Controls()
    View()


Page()
# Out:
# Html(layout=None, style_='display: none', tag='span')
# Cannot show ipywidgets in text
